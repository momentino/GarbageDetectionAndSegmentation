# %%
import sys

print(sys.path)
sys.path.append("/home/momentino/GarbageDetectionAndSegmentation")
# Out:
# ['/home/momentino/GarbageDetectionAndSegmentation/notebooks', '/usr/lib64/python310.zip', '/usr/lib64/python3.10', '/usr/lib64/python3.10/lib-dynload', '', '/home/momentino/.local/lib/python3.10/site-packages', '/usr/lib64/python3.10/site-packages', '/usr/lib/python3.10/site-packages']

# %%
# !pip install imutils
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: imutils in /home/momentino/.local/lib/python3.10/site-packages (0.5.4)

# %%
from imageio import imread
import joblib

import random as rand
import numpy as np 
import cv2
import glob
import time

import matplotlib.pyplot as plt
# %matplotlib inline

from utils import convert, show_images, put_boxes
from featuresourcer import FeatureSourcer
from binaryclassifier import BinaryClassifier
from slider import Slider

# %%
svc = joblib.load('svc.pkl')
scaler = joblib.load('scaler.pkl')

sourcer_params = {
  'color_model': 'hls',                # hls, hsv, yuv, ycrcb
  'bounding_box_w': 64,             #
  'bounding_box_h' : 48,
  'number_of_orientations': 11,        # 6 - 12
  'pixels_per_cell': 16,               # 8, 16
  'cells_per_block': 2,                # 1, 2
  'do_transform_sqrt': True
}

cls = BinaryClassifier(svc, scaler)
src = FeatureSourcer(sourcer_params, imread("/home/momentino/Scaricati/archive/garbage classification/Garbage classification/cardboard/cardboard220.jpg"))
slider = Slider(sourcer = src, classifier = cls, increment = 4)
# Out:
# /tmp/ipykernel_7065/846691397.py:15: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   src = FeatureSourcer(sourcer_params, imread("/home/momentino/Scaricati/archive/garbage classification/Garbage classification/cardboard/cardboard220.jpg"))

# %%
def bounding_boxes_test(this_image, ws, wp):
    
  boxed_images = []
  strips = []
  print("WS ",ws)
  for ws, wp in zip(ws, wp):
    print(ws, " wp ",wp)
    bounding_boxes = slider.locate(image = this_image, window_size = ws, window_position = wp)
    print("BOUNDING BOXES ",bounding_boxes)
    img = put_boxes(this_frame, bounding_boxes)
    boxed_images.append(img)
    strips.append(slider.strip())

  show_images(strips, per_row = len(strips), per_col = 1, W = 15, H = 3)
  show_images(boxed_images, per_row = len(boxed_images), per_col = 1, W = 15, H = 3)

# %%
ratio = 0.75
w_h = 48,128,196,512,2048
w_w = int(48/ratio),int(128/ratio),int(196/ratio),int(512/ratio),int(2048/ratio)
starting_y = 0, 0, 0, 0,0,0,0
starting_x = 0, 0, 0, 0,0,0,0
wp = tuple(zip(starting_x, starting_y)) 
ws = tuple(zip(w_w, w_h)) 

#wp = 0,0,0,0,0,0,0

test1 = imread("/home/momentino/TACO/data/batch_1/000066.JPG")

bounding_boxes_test(test1, ws, wp)
# Out:
# /tmp/ipykernel_7065/1949661619.py:11: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   test1 = imread("/home/momentino/TACO/data/batch_1/000066.JPG")
# WS  ((64, 48), (170, 128), (261, 196), (682, 512), (2730, 2048))
# (64, 48)  wp  (0, 0)
# X  0  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 0  y  0  h_pix  48  w_pix  64
#  x_start  0  x_end  3  y_start  0  Y_end  2
#  SLICE SHAPE  (264,)
#  FEATURE SHAPE  (792,)
# X  32  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 32  y  0  h_pix  48  w_pix  64
#  x_start  2  x_end  5  y_start  0  Y_end  2
#  SLICE SHAPE  (88,)
#  FEATURE SHAPE  (264,)
# X  64  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 64  y  0  h_pix  48  w_pix  64
#  x_start  4  x_end  7  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  96  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 96  y  0  h_pix  48  w_pix  64
#  x_start  6  x_end  9  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  128  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 128  y  0  h_pix  48  w_pix  64
#  x_start  8  x_end  11  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  160  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 160  y  0  h_pix  48  w_pix  64
#  x_start  10  x_end  13  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  192  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 192  y  0  h_pix  48  w_pix  64
#  x_start  12  x_end  15  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  224  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 224  y  0  h_pix  48  w_pix  64
#  x_start  14  x_end  17  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  256  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 256  y  0  h_pix  48  w_pix  64
#  x_start  16  x_end  19  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  288  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 288  y  0  h_pix  48  w_pix  64
#  x_start  18  x_end  21  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  320  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 320  y  0  h_pix  48  w_pix  64
#  x_start  20  x_end  23  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  352  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 352  y  0  h_pix  48  w_pix  64
#  x_start  22  x_end  25  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  384  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 384  y  0  h_pix  48  w_pix  64
#  x_start  24  x_end  27  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  416  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 416  y  0  h_pix  48  w_pix  64
#  x_start  26  x_end  29  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  448  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 448  y  0  h_pix  48  w_pix  64
#  x_start  28  x_end  31  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  480  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 480  y  0  h_pix  48  w_pix  64
#  x_start  30  x_end  33  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  512  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 512  y  0  h_pix  48  w_pix  64
#  x_start  32  x_end  35  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  544  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 544  y  0  h_pix  48  w_pix  64
#  x_start  34  x_end  37  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  576  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 576  y  0  h_pix  48  w_pix  64
#  x_start  36  x_end  39  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  608  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 608  y  0  h_pix  48  w_pix  64
#  x_start  38  x_end  41  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  640  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 640  y  0  h_pix  48  w_pix  64
#  x_start  40  x_end  43  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  672  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 672  y  0  h_pix  48  w_pix  64
#  x_start  42  x_end  45  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  704  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 704  y  0  h_pix  48  w_pix  64
#  x_start  44  x_end  47  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  736  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 736  y  0  h_pix  48  w_pix  64
#  x_start  46  x_end  49  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  768  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 768  y  0  h_pix  48  w_pix  64
#  x_start  48  x_end  51  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  800  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 800  y  0  h_pix  48  w_pix  64
#  x_start  50  x_end  53  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  832  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 832  y  0  h_pix  48  w_pix  64
#  x_start  52  x_end  55  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  864  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 864  y  0  h_pix  48  w_pix  64
#  x_start  54  x_end  57  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  896  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 896  y  0  h_pix  48  w_pix  64
#  x_start  56  x_end  59  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  928  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 928  y  0  h_pix  48  w_pix  64
#  x_start  58  x_end  61  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  960  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 960  y  0  h_pix  48  w_pix  64
#  x_start  60  x_end  63  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  992  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 992  y  0  h_pix  48  w_pix  64
#  x_start  62  x_end  65  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1024  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1024  y  0  h_pix  48  w_pix  64
#  x_start  64  x_end  67  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1056  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1056  y  0  h_pix  48  w_pix  64
#  x_start  66  x_end  69  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1088  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1088  y  0  h_pix  48  w_pix  64
#  x_start  68  x_end  71  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1120  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1120  y  0  h_pix  48  w_pix  64
#  x_start  70  x_end  73  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1152  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1152  y  0  h_pix  48  w_pix  64
#  x_start  72  x_end  75  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1184  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1184  y  0  h_pix  48  w_pix  64
#  x_start  74  x_end  77  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1216  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1216  y  0  h_pix  48  w_pix  64
#  x_start  76  x_end  79  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1248  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1248  y  0  h_pix  48  w_pix  64
#  x_start  78  x_end  81  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1280  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1280  y  0  h_pix  48  w_pix  64
#  x_start  80  x_end  83  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1312  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1312  y  0  h_pix  48  w_pix  64
#  x_start  82  x_end  85  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1344  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1344  y  0  h_pix  48  w_pix  64
#  x_start  84  x_end  87  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1376  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1376  y  0  h_pix  48  w_pix  64
#  x_start  86  x_end  89  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1408  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1408  y  0  h_pix  48  w_pix  64
#  x_start  88  x_end  91  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1440  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1440  y  0  h_pix  48  w_pix  64
#  x_start  90  x_end  93  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1472  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1472  y  0  h_pix  48  w_pix  64
#  x_start  92  x_end  95  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1504  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1504  y  0  h_pix  48  w_pix  64
#  x_start  94  x_end  97  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1536  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1536  y  0  h_pix  48  w_pix  64
#  x_start  96  x_end  99  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1568  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1568  y  0  h_pix  48  w_pix  64
#  x_start  98  x_end  101  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1600  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1600  y  0  h_pix  48  w_pix  64
#  x_start  100  x_end  103  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1632  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1632  y  0  h_pix  48  w_pix  64
#  x_start  102  x_end  105  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1664  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1664  y  0  h_pix  48  w_pix  64
#  x_start  104  x_end  107  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1696  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1696  y  0  h_pix  48  w_pix  64
#  x_start  106  x_end  109  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1728  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1728  y  0  h_pix  48  w_pix  64
#  x_start  108  x_end  111  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1760  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1760  y  0  h_pix  48  w_pix  64
#  x_start  110  x_end  113  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1792  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1792  y  0  h_pix  48  w_pix  64
#  x_start  112  x_end  115  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1824  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1824  y  0  h_pix  48  w_pix  64
#  x_start  114  x_end  117  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1856  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1856  y  0  h_pix  48  w_pix  64
#  x_start  116  x_end  119  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1888  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1888  y  0  h_pix  48  w_pix  64
#  x_start  118  x_end  121  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1920  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1920  y  0  h_pix  48  w_pix  64
#  x_start  120  x_end  123  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1952  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1952  y  0  h_pix  48  w_pix  64
#  x_start  122  x_end  125  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1984  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1984  y  0  h_pix  48  w_pix  64
#  x_start  124  x_end  127  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2016  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2016  y  0  h_pix  48  w_pix  64
#  x_start  126  x_end  129  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2048  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2048  y  0  h_pix  48  w_pix  64
#  x_start  128  x_end  131  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2080  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2080  y  0  h_pix  48  w_pix  64
#  x_start  130  x_end  133  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2112  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2112  y  0  h_pix  48  w_pix  64
#  x_start  132  x_end  135  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2144  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2144  y  0  h_pix  48  w_pix  64
#  x_start  134  x_end  137  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2176  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2176  y  0  h_pix  48  w_pix  64
#  x_start  136  x_end  139  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2208  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2208  y  0  h_pix  48  w_pix  64
#  x_start  138  x_end  141  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2240  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2240  y  0  h_pix  48  w_pix  64
#  x_start  140  x_end  143  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2272  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2272  y  0  h_pix  48  w_pix  64
#  x_start  142  x_end  145  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2304  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2304  y  0  h_pix  48  w_pix  64
#  x_start  144  x_end  147  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2336  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2336  y  0  h_pix  48  w_pix  64
#  x_start  146  x_end  149  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2368  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2368  y  0  h_pix  48  w_pix  64
#  x_start  148  x_end  151  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2400  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2400  y  0  h_pix  48  w_pix  64
#  x_start  150  x_end  153  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2432  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2432  y  0  h_pix  48  w_pix  64
#  x_start  152  x_end  155  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2464  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2464  y  0  h_pix  48  w_pix  64
#  x_start  154  x_end  157  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2496  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2496  y  0  h_pix  48  w_pix  64
#  x_start  156  x_end  159  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2528  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2528  y  0  h_pix  48  w_pix  64
#  x_start  158  x_end  161  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2560  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2560  y  0  h_pix  48  w_pix  64
#  x_start  160  x_end  163  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2592  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2592  y  0  h_pix  48  w_pix  64
#  x_start  162  x_end  165  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2624  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2624  y  0  h_pix  48  w_pix  64
#  x_start  164  x_end  167  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2656  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2656  y  0  h_pix  48  w_pix  64
#  x_start  166  x_end  169  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2688  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2688  y  0  h_pix  48  w_pix  64
#  x_start  168  x_end  171  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2720  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2720  y  0  h_pix  48  w_pix  64
#  x_start  170  x_end  173  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2752  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2752  y  0  h_pix  48  w_pix  64
#  x_start  172  x_end  175  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2784  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2784  y  0  h_pix  48  w_pix  64
#  x_start  174  x_end  177  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2816  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2816  y  0  h_pix  48  w_pix  64
#  x_start  176  x_end  179  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2848  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2848  y  0  h_pix  48  w_pix  64
#  x_start  178  x_end  181  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2880  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2880  y  0  h_pix  48  w_pix  64
#  x_start  180  x_end  183  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2912  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2912  y  0  h_pix  48  w_pix  64
#  x_start  182  x_end  185  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2944  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2944  y  0  h_pix  48  w_pix  64
#  x_start  184  x_end  187  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2976  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2976  y  0  h_pix  48  w_pix  64
#  x_start  186  x_end  189  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  3008  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 3008  y  0  h_pix  48  w_pix  64
#  x_start  188  x_end  191  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  3040  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 3040  y  0  h_pix  48  w_pix  64
#  x_start  190  x_end  193  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  3072  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 3072  y  0  h_pix  48  w_pix  64
#  x_start  192  x_end  195  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  3104  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 3104  y  0  h_pix  48  w_pix  64
#  x_start  194  x_end  197  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  3136  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 3136  y  0  h_pix  48  w_pix  64
#  x_start  196  x_end  199  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  3168  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 3168  y  0  h_pix  48  w_pix  64
#  x_start  198  x_end  201  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  3200  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 3200  y  0  h_pix  48  w_pix  64
#  x_start  200  x_end  203  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  0  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 0  y  32  h_pix  48  w_pix  64
#  x_start  0  x_end  3  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  32  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 32  y  32  h_pix  48  w_pix  64
#  x_start  2  x_end  5  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  64  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 64  y  32  h_pix  48  w_pix  64
#  x_start  4  x_end  7  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  96  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 96  y  32  h_pix  48  w_pix  64
#  x_start  6  x_end  9  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  128  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 128  y  32  h_pix  48  w_pix  64
#  x_start  8  x_end  11  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  160  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 160  y  32  h_pix  48  w_pix  64
#  x_start  10  x_end  13  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  192  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 192  y  32  h_pix  48  w_pix  64
#  x_start  12  x_end  15  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  224  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 224  y  32  h_pix  48  w_pix  64
#  x_start  14  x_end  17  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  256  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 256  y  32  h_pix  48  w_pix  64
#  x_start  16  x_end  19  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  288  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 288  y  32  h_pix  48  w_pix  64
#  x_start  18  x_end  21  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  320  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 320  y  32  h_pix  48  w_pix  64
#  x_start  20  x_end  23  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  352  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 352  y  32  h_pix  48  w_pix  64
#  x_start  22  x_end  25  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  384  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 384  y  32  h_pix  48  w_pix  64
#  x_start  24  x_end  27  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  416  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 416  y  32  h_pix  48  w_pix  64
#  x_start  26  x_end  29  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  448  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 448  y  32  h_pix  48  w_pix  64
#  x_start  28  x_end  31  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  480  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 480  y  32  h_pix  48  w_pix  64
#  x_start  30  x_end  33  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  512  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 512  y  32  h_pix  48  w_pix  64
#  x_start  32  x_end  35  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  544  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 544  y  32  h_pix  48  w_pix  64
#  x_start  34  x_end  37  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  576  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 576  y  32  h_pix  48  w_pix  64
#  x_start  36  x_end  39  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  608  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 608  y  32  h_pix  48  w_pix  64
#  x_start  38  x_end  41  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  640  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 640  y  32  h_pix  48  w_pix  64
#  x_start  40  x_end  43  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  672  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 672  y  32  h_pix  48  w_pix  64
#  x_start  42  x_end  45  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  704  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 704  y  32  h_pix  48  w_pix  64
#  x_start  44  x_end  47  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  736  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 736  y  32  h_pix  48  w_pix  64
#  x_start  46  x_end  49  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  768  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 768  y  32  h_pix  48  w_pix  64
#  x_start  48  x_end  51  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  800  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 800  y  32  h_pix  48  w_pix  64
#  x_start  50  x_end  53  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  832  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 832  y  32  h_pix  48  w_pix  64
#  x_start  52  x_end  55  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  864  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 864  y  32  h_pix  48  w_pix  64
#  x_start  54  x_end  57  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  896  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 896  y  32  h_pix  48  w_pix  64
#  x_start  56  x_end  59  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  928  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 928  y  32  h_pix  48  w_pix  64
#  x_start  58  x_end  61  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  960  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 960  y  32  h_pix  48  w_pix  64
#  x_start  60  x_end  63  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  992  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 992  y  32  h_pix  48  w_pix  64
#  x_start  62  x_end  65  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1024  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1024  y  32  h_pix  48  w_pix  64
#  x_start  64  x_end  67  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1056  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1056  y  32  h_pix  48  w_pix  64
#  x_start  66  x_end  69  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1088  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1088  y  32  h_pix  48  w_pix  64
#  x_start  68  x_end  71  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1120  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1120  y  32  h_pix  48  w_pix  64
#  x_start  70  x_end  73  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1152  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1152  y  32  h_pix  48  w_pix  64
#  x_start  72  x_end  75  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1184  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1184  y  32  h_pix  48  w_pix  64
#  x_start  74  x_end  77  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1216  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1216  y  32  h_pix  48  w_pix  64
#  x_start  76  x_end  79  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1248  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1248  y  32  h_pix  48  w_pix  64
#  x_start  78  x_end  81  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1280  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1280  y  32  h_pix  48  w_pix  64
#  x_start  80  x_end  83  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1312  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1312  y  32  h_pix  48  w_pix  64
#  x_start  82  x_end  85  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1344  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1344  y  32  h_pix  48  w_pix  64
#  x_start  84  x_end  87  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1376  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1376  y  32  h_pix  48  w_pix  64
#  x_start  86  x_end  89  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1408  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1408  y  32  h_pix  48  w_pix  64
#  x_start  88  x_end  91  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1440  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1440  y  32  h_pix  48  w_pix  64
#  x_start  90  x_end  93  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1472  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1472  y  32  h_pix  48  w_pix  64
#  x_start  92  x_end  95  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1504  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1504  y  32  h_pix  48  w_pix  64
#  x_start  94  x_end  97  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1536  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1536  y  32  h_pix  48  w_pix  64
#  x_start  96  x_end  99  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1568  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1568  y  32  h_pix  48  w_pix  64
#  x_start  98  x_end  101  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1600  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1600  y  32  h_pix  48  w_pix  64
#  x_start  100  x_end  103  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1632  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1632  y  32  h_pix  48  w_pix  64
#  x_start  102  x_end  105  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1664  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1664  y  32  h_pix  48  w_pix  64
#  x_start  104  x_end  107  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1696  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1696  y  32  h_pix  48  w_pix  64
#  x_start  106  x_end  109  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1728  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1728  y  32  h_pix  48  w_pix  64
#  x_start  108  x_end  111  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1760  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1760  y  32  h_pix  48  w_pix  64
#  x_start  110  x_end  113  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1792  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1792  y  32  h_pix  48  w_pix  64
#  x_start  112  x_end  115  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1824  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1824  y  32  h_pix  48  w_pix  64
#  x_start  114  x_end  117  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1856  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1856  y  32  h_pix  48  w_pix  64
#  x_start  116  x_end  119  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1888  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1888  y  32  h_pix  48  w_pix  64
#  x_start  118  x_end  121  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1920  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1920  y  32  h_pix  48  w_pix  64
#  x_start  120  x_end  123  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1952  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1952  y  32  h_pix  48  w_pix  64
#  x_start  122  x_end  125  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1984  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1984  y  32  h_pix  48  w_pix  64
#  x_start  124  x_end  127  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2016  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2016  y  32  h_pix  48  w_pix  64
#  x_start  126  x_end  129  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2048  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2048  y  32  h_pix  48  w_pix  64
#  x_start  128  x_end  131  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2080  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2080  y  32  h_pix  48  w_pix  64
#  x_start  130  x_end  133  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2112  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2112  y  32  h_pix  48  w_pix  64
#  x_start  132  x_end  135  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2144  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2144  y  32  h_pix  48  w_pix  64
#  x_start  134  x_end  137  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2176  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2176  y  32  h_pix  48  w_pix  64
#  x_start  136  x_end  139  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2208  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2208  y  32  h_pix  48  w_pix  64
#  x_start  138  x_end  141  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2240  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2240  y  32  h_pix  48  w_pix  64
#  x_start  140  x_end  143  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2272  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2272  y  32  h_pix  48  w_pix  64
#  x_start  142  x_end  145  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2304  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2304  y  32  h_pix  48  w_pix  64
#  x_start  144  x_end  147  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2336  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2336  y  32  h_pix  48  w_pix  64
#  x_start  146  x_end  149  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2368  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2368  y  32  h_pix  48  w_pix  64
#  x_start  148  x_end  151  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2400  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2400  y  32  h_pix  48  w_pix  64
#  x_start  150  x_end  153  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2432  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2432  y  32  h_pix  48  w_pix  64
#  x_start  152  x_end  155  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2464  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2464  y  32  h_pix  48  w_pix  64
#  x_start  154  x_end  157  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2496  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2496  y  32  h_pix  48  w_pix  64
#  x_start  156  x_end  159  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2528  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2528  y  32  h_pix  48  w_pix  64
#  x_start  158  x_end  161  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2560  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2560  y  32  h_pix  48  w_pix  64
#  x_start  160  x_end  163  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2592  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2592  y  32  h_pix  48  w_pix  64
#  x_start  162  x_end  165  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2624  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2624  y  32  h_pix  48  w_pix  64
#  x_start  164  x_end  167  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2656  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2656  y  32  h_pix  48  w_pix  64
#  x_start  166  x_end  169  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2688  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2688  y  32  h_pix  48  w_pix  64
#  x_start  168  x_end  171  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2720  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2720  y  32  h_pix  48  w_pix  64
#  x_start  170  x_end  173  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2752  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2752  y  32  h_pix  48  w_pix  64
#  x_start  172  x_end  175  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2784  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2784  y  32  h_pix  48  w_pix  64
#  x_start  174  x_end  177  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2816  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2816  y  32  h_pix  48  w_pix  64
#  x_start  176  x_end  179  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2848  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2848  y  32  h_pix  48  w_pix  64
#  x_start  178  x_end  181  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2880  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2880  y  32  h_pix  48  w_pix  64
#  x_start  180  x_end  183  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2912  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2912  y  32  h_pix  48  w_pix  64
#  x_start  182  x_end  185  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2944  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2944  y  32  h_pix  48  w_pix  64
#  x_start  184  x_end  187  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  2976  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 2976  y  32  h_pix  48  w_pix  64
#  x_start  186  x_end  189  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  3008  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 3008  y  32  h_pix  48  w_pix  64
#  x_start  188  x_end  191  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  3040  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 3040  y  32  h_pix  48  w_pix  64
#  x_start  190  x_end  193  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  3072  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 3072  y  32  h_pix  48  w_pix  64
#  x_start  192  x_end  195  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  3104  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 3104  y  32  h_pix  48  w_pix  64
#  x_start  194  x_end  197  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  3136  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 3136  y  32  h_pix  48  w_pix  64
#  x_start  196  x_end  199  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  3168  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 3168  y  32  h_pix  48  w_pix  64
#  x_start  198  x_end  201  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  3200  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 3200  y  32  h_pix  48  w_pix  64
#  x_start  200  x_end  203  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  0  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 0  y  64  h_pix  48  w_pix  64
#  x_start  0  x_end  3  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  32  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 32  y  64  h_pix  48  w_pix  64
#  x_start  2  x_end  5  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  64  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 64  y  64  h_pix  48  w_pix  64
#  x_start  4  x_end  7  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  96  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 96  y  64  h_pix  48  w_pix  64
#  x_start  6  x_end  9  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  128  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 128  y  64  h_pix  48  w_pix  64
#  x_start  8  x_end  11  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  160  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 160  y  64  h_pix  48  w_pix  64
#  x_start  10  x_end  13  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  192  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 192  y  64  h_pix  48  w_pix  64
#  x_start  12  x_end  15  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  224  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 224  y  64  h_pix  48  w_pix  64
#  x_start  14  x_end  17  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  256  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 256  y  64  h_pix  48  w_pix  64
#  x_start  16  x_end  19  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  288  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 288  y  64  h_pix  48  w_pix  64
#  x_start  18  x_end  21  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  320  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 320  y  64  h_pix  48  w_pix  64
#  x_start  20  x_end  23  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  352  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 352  y  64  h_pix  48  w_pix  64
#  x_start  22  x_end  25  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  384  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 384  y  64  h_pix  48  w_pix  64
#  x_start  24  x_end  27  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  416  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 416  y  64  h_pix  48  w_pix  64
#  x_start  26  x_end  29  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  448  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 448  y  64  h_pix  48  w_pix  64
#  x_start  28  x_end  31  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  480  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 480  y  64  h_pix  48  w_pix  64
#  x_start  30  x_end  33  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  512  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 512  y  64  h_pix  48  w_pix  64
#  x_start  32  x_end  35  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  544  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 544  y  64  h_pix  48  w_pix  64
#  x_start  34  x_end  37  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  576  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 576  y  64  h_pix  48  w_pix  64
#  x_start  36  x_end  39  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  608  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 608  y  64  h_pix  48  w_pix  64
#  x_start  38  x_end  41  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  640  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 640  y  64  h_pix  48  w_pix  64
#  x_start  40  x_end  43  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  672  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 672  y  64  h_pix  48  w_pix  64
#  x_start  42  x_end  45  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  704  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 704  y  64  h_pix  48  w_pix  64
#  x_start  44  x_end  47  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  736  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 736  y  64  h_pix  48  w_pix  64
#  x_start  46  x_end  49  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  768  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 768  y  64  h_pix  48  w_pix  64
#  x_start  48  x_end  51  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  800  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 800  y  64  h_pix  48  w_pix  64
#  x_start  50  x_end  53  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  832  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 832  y  64  h_pix  48  w_pix  64
#  x_start  52  x_end  55  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  864  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 864  y  64  h_pix  48  w_pix  64
#  x_start  54  x_end  57  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  896  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 896  y  64  h_pix  48  w_pix  64
#  x_start  56  x_end  59  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  928  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 928  y  64  h_pix  48  w_pix  64
#  x_start  58  x_end  61  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  960  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 960  y  64  h_pix  48  w_pix  64
#  x_start  60  x_end  63  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  992  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 992  y  64  h_pix  48  w_pix  64
#  x_start  62  x_end  65  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1024  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1024  y  64  h_pix  48  w_pix  64
#  x_start  64  x_end  67  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1056  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1056  y  64  h_pix  48  w_pix  64
#  x_start  66  x_end  69  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1088  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1088  y  64  h_pix  48  w_pix  64
#  x_start  68  x_end  71  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1120  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1120  y  64  h_pix  48  w_pix  64
#  x_start  70  x_end  73  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1152  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1152  y  64  h_pix  48  w_pix  64
#  x_start  72  x_end  75  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1184  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1184  y  64  h_pix  48  w_pix  64
#  x_start  74  x_end  77  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1216  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1216  y  64  h_pix  48  w_pix  64
#  x_start  76  x_end  79  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1248  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1248  y  64  h_pix  48  w_pix  64
#  x_start  78  x_end  81  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1280  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1280  y  64  h_pix  48  w_pix  64
#  x_start  80  x_end  83  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  1312  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 1312  y  64  h_pix  48  w_pix  64
#  x_start  82  x_end  85  y_start  4  Y_end  6
# ...
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  128  Y  224  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 128  y  224  h_pix  48  w_pix  64
#  x_start  8  x_end  11  y_start  14  Y_end  16
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  160  Y  224  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 160  y  224  h_pix  48  w_pix  64
#  x_start  10  x_end  13  y_start  14  Y_end  16
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  192  Y  224  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 192  y  224  h_pix  48  w_pix  64
#  x_start  12  x_end  15  y_start  14  Y_end  16
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  224  Y  224  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 224  y  224  h_pix  48  w_pix  64
#  x_start  14  x_end  17  y_start  14  Y_end  16
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  256  Y  224  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 256  y  224  h_pix  48  w_pix  64
#  x_start  16  x_end  19  y_start  14  Y_end  16
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  288  Y  224  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 288  y  224  h_pix  48  w_pix  64
#  x_start  18  x_end  21  y_start  14  Y_end  16
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  320  Y  224  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 320  y  224  h_pix  48  w_pix  64
#  x_start  20  x_end  23  y_start  14  Y_end  16
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  352  Y  224  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 352  y  224  h_pix  48  w_pix  64
#  x_start  22  x_end  25  y_start  14  Y_end  16
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  0  Y  256  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 0  y  256  h_pix  48  w_pix  64
#  x_start  0  x_end  3  y_start  16  Y_end  18
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  32  Y  256  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 32  y  256  h_pix  48  w_pix  64
#  x_start  2  x_end  5  y_start  16  Y_end  18
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  64  Y  256  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 64  y  256  h_pix  48  w_pix  64
#  x_start  4  x_end  7  y_start  16  Y_end  18
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  96  Y  256  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 96  y  256  h_pix  48  w_pix  64
#  x_start  6  x_end  9  y_start  16  Y_end  18
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  128  Y  256  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 128  y  256  h_pix  48  w_pix  64
#  x_start  8  x_end  11  y_start  16  Y_end  18
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  160  Y  256  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 160  y  256  h_pix  48  w_pix  64
#  x_start  10  x_end  13  y_start  16  Y_end  18
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  192  Y  256  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 192  y  256  h_pix  48  w_pix  64
#  x_start  12  x_end  15  y_start  16  Y_end  18
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  224  Y  256  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 224  y  256  h_pix  48  w_pix  64
#  x_start  14  x_end  17  y_start  16  Y_end  18
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  256  Y  256  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 256  y  256  h_pix  48  w_pix  64
#  x_start  16  x_end  19  y_start  16  Y_end  18
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  288  Y  256  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 288  y  256  h_pix  48  w_pix  64
#  x_start  18  x_end  21  y_start  16  Y_end  18
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  320  Y  256  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 320  y  256  h_pix  48  w_pix  64
#  x_start  20  x_end  23  y_start  16  Y_end  18
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  352  Y  256  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 352  y  256  h_pix  48  w_pix  64
#  x_start  22  x_end  25  y_start  16  Y_end  18
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  0  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 0  y  0  h_pix  48  w_pix  64
#  x_start  0  x_end  3  y_start  0  Y_end  2
#  SLICE SHAPE  (264,)
#  FEATURE SHAPE  (792,)
# X  32  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 32  y  0  h_pix  48  w_pix  64
#  x_start  2  x_end  5  y_start  0  Y_end  2
#  SLICE SHAPE  (88,)
#  FEATURE SHAPE  (264,)
# X  64  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 64  y  0  h_pix  48  w_pix  64
#  x_start  4  x_end  7  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  96  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 96  y  0  h_pix  48  w_pix  64
#  x_start  6  x_end  9  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  128  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 128  y  0  h_pix  48  w_pix  64
#  x_start  8  x_end  11  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  160  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 160  y  0  h_pix  48  w_pix  64
#  x_start  10  x_end  13  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  192  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 192  y  0  h_pix  48  w_pix  64
#  x_start  12  x_end  15  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  0  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 0  y  32  h_pix  48  w_pix  64
#  x_start  0  x_end  3  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  32  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 32  y  32  h_pix  48  w_pix  64
#  x_start  2  x_end  5  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  64  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 64  y  32  h_pix  48  w_pix  64
#  x_start  4  x_end  7  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  96  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 96  y  32  h_pix  48  w_pix  64
#  x_start  6  x_end  9  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  128  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 128  y  32  h_pix  48  w_pix  64
#  x_start  8  x_end  11  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  160  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 160  y  32  h_pix  48  w_pix  64
#  x_start  10  x_end  13  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  192  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 192  y  32  h_pix  48  w_pix  64
#  x_start  12  x_end  15  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  0  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 0  y  64  h_pix  48  w_pix  64
#  x_start  0  x_end  3  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  32  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 32  y  64  h_pix  48  w_pix  64
#  x_start  2  x_end  5  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  64  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 64  y  64  h_pix  48  w_pix  64
#  x_start  4  x_end  7  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  96  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 96  y  64  h_pix  48  w_pix  64
#  x_start  6  x_end  9  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  128  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 128  y  64  h_pix  48  w_pix  64
#  x_start  8  x_end  11  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  160  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 160  y  64  h_pix  48  w_pix  64
#  x_start  10  x_end  13  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  192  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 192  y  64  h_pix  48  w_pix  64
#  x_start  12  x_end  15  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  0  Y  96  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 0  y  96  h_pix  48  w_pix  64
#  x_start  0  x_end  3  y_start  6  Y_end  8
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  32  Y  96  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 32  y  96  h_pix  48  w_pix  64
#  x_start  2  x_end  5  y_start  6  Y_end  8
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  64  Y  96  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 64  y  96  h_pix  48  w_pix  64
#  x_start  4  x_end  7  y_start  6  Y_end  8
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  96  Y  96  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 96  y  96  h_pix  48  w_pix  64
#  x_start  6  x_end  9  y_start  6  Y_end  8
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  128  Y  96  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 128  y  96  h_pix  48  w_pix  64
#  x_start  8  x_end  11  y_start  6  Y_end  8
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  160  Y  96  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 160  y  96  h_pix  48  w_pix  64
#  x_start  10  x_end  13  y_start  6  Y_end  8
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  192  Y  96  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 192  y  96  h_pix  48  w_pix  64
#  x_start  12  x_end  15  y_start  6  Y_end  8
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  0  Y  128  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 0  y  128  h_pix  48  w_pix  64
#  x_start  0  x_end  3  y_start  8  Y_end  10
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  32  Y  128  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 32  y  128  h_pix  48  w_pix  64
#  x_start  2  x_end  5  y_start  8  Y_end  10
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  64  Y  128  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 64  y  128  h_pix  48  w_pix  64
#  x_start  4  x_end  7  y_start  8  Y_end  10
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  96  Y  128  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 96  y  128  h_pix  48  w_pix  64
#  x_start  6  x_end  9  y_start  8  Y_end  10
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  128  Y  128  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 128  y  128  h_pix  48  w_pix  64
#  x_start  8  x_end  11  y_start  8  Y_end  10
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  160  Y  128  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 160  y  128  h_pix  48  w_pix  64
#  x_start  10  x_end  13  y_start  8  Y_end  10
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  192  Y  128  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 192  y  128  h_pix  48  w_pix  64
#  x_start  12  x_end  15  y_start  8  Y_end  10
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  0  Y  160  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 0  y  160  h_pix  48  w_pix  64
#  x_start  0  x_end  3  y_start  10  Y_end  12
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  32  Y  160  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 32  y  160  h_pix  48  w_pix  64
#  x_start  2  x_end  5  y_start  10  Y_end  12
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  64  Y  160  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 64  y  160  h_pix  48  w_pix  64
#  x_start  4  x_end  7  y_start  10  Y_end  12
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  96  Y  160  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 96  y  160  h_pix  48  w_pix  64
#  x_start  6  x_end  9  y_start  10  Y_end  12
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  128  Y  160  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 128  y  160  h_pix  48  w_pix  64
#  x_start  8  x_end  11  y_start  10  Y_end  12
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  160  Y  160  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 160  y  160  h_pix  48  w_pix  64
#  x_start  10  x_end  13  y_start  10  Y_end  12
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  192  Y  160  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 192  y  160  h_pix  48  w_pix  64
#  x_start  12  x_end  15  y_start  10  Y_end  12
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  0  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 0  y  0  h_pix  48  w_pix  64
#  x_start  0  x_end  3  y_start  0  Y_end  2
#  SLICE SHAPE  (264,)
#  FEATURE SHAPE  (792,)
# X  32  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 32  y  0  h_pix  48  w_pix  64
#  x_start  2  x_end  5  y_start  0  Y_end  2
#  SLICE SHAPE  (88,)
#  FEATURE SHAPE  (264,)
# X  64  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 64  y  0  h_pix  48  w_pix  64
#  x_start  4  x_end  7  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  96  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 96  y  0  h_pix  48  w_pix  64
#  x_start  6  x_end  9  y_start  0  Y_end  2
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  0  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 0  y  32  h_pix  48  w_pix  64
#  x_start  0  x_end  3  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  32  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 32  y  32  h_pix  48  w_pix  64
#  x_start  2  x_end  5  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  64  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 64  y  32  h_pix  48  w_pix  64
#  x_start  4  x_end  7  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  96  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 96  y  32  h_pix  48  w_pix  64
#  x_start  6  x_end  9  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  0  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 0  y  64  h_pix  48  w_pix  64
#  x_start  0  x_end  3  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  32  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 32  y  64  h_pix  48  w_pix  64
#  x_start  2  x_end  5  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  64  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 64  y  64  h_pix  48  w_pix  64
#  x_start  4  x_end  7  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  96  Y  64  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 96  y  64  h_pix  48  w_pix  64
#  x_start  6  x_end  9  y_start  4  Y_end  6
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  0  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 0  y  0  h_pix  48  w_pix  64
#  x_start  0  x_end  3  y_start  0  Y_end  2
#  SLICE SHAPE  (264,)
#  FEATURE SHAPE  (792,)
# X  32  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 32  y  0  h_pix  48  w_pix  64
#  x_start  2  x_end  5  y_start  0  Y_end  2
#  SLICE SHAPE  (88,)
#  FEATURE SHAPE  (264,)
# X  0  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 0  y  32  h_pix  48  w_pix  64
#  x_start  0  x_end  3  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  32  Y  32  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 32  y  32  h_pix  48  w_pix  64
#  x_start  2  x_end  5  y_start  2  Y_end  4
#  SLICE SHAPE  (0,)
#  FEATURE SHAPE  (0,)
# X  0  Y  0  W_W  64  W_H  48 WINDOW SHAPE  (48, 64, 3)
#  PIX TO HOG DI x 0  y  0  h_pix  48  w_pix  64
#  x_start  0  x_end  3  y_start  0  Y_end  2
#  SLICE SHAPE  (264,)
#  FEATURE SHAPE  (792,)
# BOUNDING BOXES  []
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 13
#       9 #wp = 0,0,0,0,0,0,0
#      11 test1 = imread("/home/momentino/TACO/data/batch_1/000066.JPG")
# ---> 13 bounding_boxes_test(test1, ws, wp)
#
# Cell In[5], line 10, in bounding_boxes_test(this_image, ws, wp)
#       8 bounding_boxes = slider.locate(image = this_image, window_size = ws, window_position = wp)
#       9 print("BOUNDING BOXES ",bounding_boxes)
# ---> 10 img = put_boxes(this_frame, bounding_boxes)
#      11 boxed_images.append(img)
#      12 strips.append(slider.strip())
#
# NameError: name 'this_frame' is not defined

# %%
test2 = imread("/home/momentino/TACO/data/batch_1/000029.jpg")

bounding_boxes_test(test2, ws, wp)
